# %%
# Render plots inline
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
time = [0, 1, 2, 3]
position = [0, 100, 200, 300]

plt.plot(time, position)
plt.xlabel('Time (hr)')
plt.ylabel('Position (km)')

# %% [markdown]
# # Plot from Pandas dataframe
# Uses matplotlib.pyplot

# %%
import pandas

data = pandas.read_csv('data/gapminder_gdp_oceania.csv', index_col='country')
data.loc['Australia'].plot()
plt.xticks(rotation=90)
# Out:
# (array([  0.,   2.,   4.,   6.,   8.,  10.,  12.]),
#  <a list of 7 Text xticklabel objects>)

# %%
#Transpose data then plot multiple series
data.T.plot()
plt.ylabel('GDP per capita')
plt.xticks(rotation=90)
# Out:
# (array([  0.,   2.,   4.,   6.,   8.,  10.,  12.]),
#  <a list of 7 Text xticklabel objects>)

# %%
#Change plot style
plt.style.use('ggplot')
data.T.plot(kind='bar')
plt.xticks(rotation=90)
plt.ylabel('GDP per capita')

# %%
#Extract years from column names
years = data.columns.str.strip('gdpPercap_')
gdp_australia = data.loc['Australia']
#Set line style as -------
plt.plot(years, gdp_australia, 'g--')
plt.ylabel('GDP per capita')

# %%
#Plot multiple datasets
# Select two countries' worth of data.
gdp_australia = data.loc['Australia']
gdp_nz = data.loc['New Zealand']

# Plot with differently-colored markers.
plt.plot(years, gdp_australia, 'b-', label='Australia')
plt.plot(years, gdp_nz, 'g-', label='New Zealand')

# Create legend.
plt.legend(loc='upper left')
plt.xlabel('Year')
plt.ylabel('GDP per capita ($)')

# %%
#Scatter plot to compare GDP of Australia and New Zealand
#Can use ply.scatter datafram.plot.scatter
plt.scatter(gdp_australia, gdp_nz)
plt.ylabel('New Zealand GDP')
plt.xlabel('Australia GDP')

# %%
data.T.plot.scatter(x = 'Australia', y = 'New Zealand')

# %%
#Plot minimum GDP per capita for all countries in Europe
data_europe = pandas.read_csv('data/gapminder_gdp_europe.csv', index_col='country')
data_europe.min().plot(label='min')
data_europe.max().plot(label='max')
plt.legend(loc='best')
plt.xticks(rotation=90)
# Out:
# (array([  0.,   2.,   4.,   6.,   8.,  10.,  12.]),
#  <a list of 7 Text xticklabel objects>)

# %%
#Compare max and min GDP for Asia in each year
data_asia = pandas.read_csv('data/gapminder_gdp_asia.csv', index_col='country')
data_asia.describe().T.plot(kind='scatter', x='min', y='max')

# %%
#Plot GDP again life expectancy and normalise marker size by population
# s sets the size of marker, in this case divided by 1e^6
data_all = pandas.read_csv('data/gapminder_all.csv', index_col='country')
data_all.plot(kind='scatter', x='gdpPercap_2007', y='lifeExp_2007',
              s=data_all['pop_2007']/1e6)
